# %% [markdown]
# # Mini Project: High-Performance Computing and Computer Vision
#
# # Track C: JIT Compilation
#
# Project submission is located here:
# * [Project submission](../project/project.md)

# %% [markdown]
# # Setup

# %% [markdown]
# ## Environment setup
#
# Install required libraries for object detection (Ultralytics YOLO), dataset loading (Hugging Face), image handling (OpenCV+pillow), and JIT compilation (Numba).

# %%
# !pip install ultralytics datasets opencv-python pillow numba
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.4.41)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (0.60.0)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.19)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.10.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba) (0.43.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (0.1.2)

# %% [markdown]
# ## Test Setup

# %% [markdown]
# ### Get Image dataset
# 160 images of traffic from Hugging Face dataset

# %%
#from huggingface_hub import login
#login("YYY")

# %%
import os
from pathlib import Path

image_dir = Path("traffic_images")
image_dir.mkdir(exist_ok=True)

# Check if images already exist
existing_images = list(image_dir.glob("*.jpg"))

if len(existing_images) > 0:
    print(f"Found {len(existing_images)} existing images. Skipping download.")
    image_paths = [str(p) for p in existing_images]

else:
    print("No saved images found. Downloading dataset and saving images...")

    from datasets import load_dataset
    dataset = load_dataset("AITC-Traffic-Density/Traffic-Object-Detection")

    image_paths = []

    for split_name in dataset.keys():
        for i, item in enumerate(dataset[split_name]):
            img = item["image"]
            path = image_dir / f"{split_name}_img_{i}.jpg"
            img.save(path)
            image_paths.append(str(path))

    print(f"Saved {len(image_paths)} images to {image_dir}")

print("First 5 paths:", image_paths[:5])
# Out:
# Found 160 existing images. Skipping download.
# First 5 paths: ['traffic_images/test_img_9.jpg', 'traffic_images/train_img_78.jpg', 'traffic_images/train_img_46.jpg', 'traffic_images/validation_img_0.jpg', 'traffic_images/train_img_39.jpg']

# %% [markdown]
# ## Run inference

# %%
import random
import numpy as np
from ultralytics import YOLO

# --- Load model ---
model = YOLO("yolov8n.pt")  # adjust if needed

# --- Collect all image paths ---
#image_paths = [str(p) for p in image_dir.glob("*.jpg")]

# --- Sample 1 random images ---
# sample_paths = random.sample(image_paths, min(1, len(image_paths)))
sample_paths = image_paths # do all

# --- Storage for later use ---
all_boxes = []
all_scores = []
all_classes = []

# --- Stats tracking ---
num_boxes_list = []

print("Running inference on images...\n")

for i, path in enumerate(sample_paths, 1):
    result = model.predict(path, conf=0.1, verbose=False)[0]

    boxes = result.boxes.xyxy.cpu().numpy()
    scores = result.boxes.conf.cpu().numpy()
    classes = result.boxes.cls.cpu().numpy()

    num_boxes = len(boxes)
    num_cars = np.sum(classes == 2)     # class 2 = car
    num_persons = np.sum(classes == 0)  # class 0 = person
    avg_conf = float(scores.mean()) if num_boxes > 0 else 0.0

    num_boxes_list.append(num_boxes)

    all_boxes.append(boxes)
    all_scores.append(scores)
    all_classes.append(classes)

    print(f"Image {i}:")
    print(f"  total boxes: {num_boxes}")
    print(f"  cars: {num_cars}")
    print(f"  persons: {num_persons}")
    print(f"  avg confidence: {avg_conf:.3f}\n")

# --- Summary ---
if num_boxes_list:
    print("Summary:")
    print(f"  avg boxes/image: {np.mean(num_boxes_list):.2f}")
    print(f"  max boxes/image: {np.max(num_boxes_list)}")
    print(f"  min boxes/image: {np.min(num_boxes_list)}")
else:
    print("No detections found.")

# --- Flatten all boxes for future IoU / JIT experiments ---
if all_boxes:
    flat_boxes = np.vstack([b for b in all_boxes if len(b) > 0]) if any(len(b) > 0 for b in all_boxes) else np.empty((0, 4))
    print(f"\nTotal boxes across all images: {len(flat_boxes)}")
# Out:
# Running inference on images...
#
# Image 1:
#   total boxes: 18
#   cars: 15
#   persons: 0
#   avg confidence: 0.269
#
# Image 2:
#   total boxes: 11
#   cars: 6
#   persons: 2
#   avg confidence: 0.275
#
# Image 3:
#   total boxes: 3
#   cars: 2
#   persons: 0
#   avg confidence: 0.301
#
# Image 4:
#   total boxes: 34
#   cars: 29
#   persons: 0
#   avg confidence: 0.379
#
# Image 5:
#   total boxes: 2
#   cars: 0
#   persons: 0
#   avg confidence: 0.286
#
# Image 6:
#   total boxes: 18
#   cars: 11
#   persons: 0
#   avg confidence: 0.324
#
# Image 7:
#   total boxes: 0
#   cars: 0
#   persons: 0
#   avg confidence: 0.000
#
# Image 8:
#   total boxes: 3
#   cars: 0
#   persons: 0
#   avg confidence: 0.127
#
# Image 9:
#   total boxes: 1
#   cars: 0
#   persons: 0
#   avg confidence: 0.407
#
# Image 10:
#   total boxes: 9
#   cars: 3
#   persons: 0
#   avg confidence: 0.250
#
# Image 11:
#   total boxes: 8
#   cars: 5
#   persons: 1
#   avg confidence: 0.399
#
# Image 12:
#   total boxes: 8
#   cars: 0
#   persons: 1
#   avg confidence: 0.172
#
# Image 13:
#   total boxes: 2
#   cars: 0
#   persons: 0
#   avg confidence: 0.226
#
# Image 14:
#   total boxes: 13
#   cars: 7
#   persons: 1
#   avg confidence: 0.305
#
# Image 15:
#   total boxes: 3
#   cars: 0
#   persons: 0
#   avg confidence: 0.186
#
# Image 16:
#   total boxes: 12
#   cars: 8
#   persons: 0
#   avg confidence: 0.232
#
# Image 17:
#   total boxes: 7
#   cars: 2
#   persons: 0
#   avg confidence: 0.255
#
# Image 18:
#   total boxes: 10
#   cars: 3
#   persons: 0
#   avg confidence: 0.157
#
# Image 19:
#   total boxes: 8
#   cars: 5
#   persons: 0
#   avg confidence: 0.201
#
# Image 20:
#   total boxes: 3
#   cars: 2
#   persons: 0
#   avg confidence: 0.303
#
# Image 21:
#   total boxes: 6
#   cars: 6
#   persons: 0
#   avg confidence: 0.419
#
# Image 22:
#   total boxes: 2
#   cars: 0
#   persons: 0
#   avg confidence: 0.167
#
# Image 23:
#   total boxes: 6
#   cars: 3
#   persons: 0
#   avg confidence: 0.272
#
# Image 24:
#   total boxes: 4
#   cars: 2
#   persons: 0
#   avg confidence: 0.396
#
# Image 25:
#   total boxes: 6
#   cars: 4
#   persons: 0
#   avg confidence: 0.206
#
# Image 26:
#   total boxes: 4
#   cars: 0
#   persons: 0
#   avg confidence: 0.173
#
# Image 27:
#   total boxes: 5
#   cars: 2
#   persons: 0
#   avg confidence: 0.279
#
# Image 28:
#   total boxes: 1
#   cars: 0
#   persons: 0
#   avg confidence: 0.534
#
# Image 29:
#   total boxes: 15
#   cars: 12
#   persons: 0
#   avg confidence: 0.438
#
# Image 30:
#   total boxes: 5
#   cars: 1
#   persons: 1
#   avg confidence: 0.196
#
# Image 31:
#   total boxes: 4
#   cars: 2
#   persons: 0
#   avg confidence: 0.427
#
# Image 32:
#   total boxes: 24
#   cars: 21
#   persons: 0
#   avg confidence: 0.367
#
# Image 33:
#   total boxes: 3
#   cars: 2
#   persons: 0
#   avg confidence: 0.512
#
# Image 34:
#   total boxes: 10
#   cars: 1
#   persons: 0
#   avg confidence: 0.226
#
# Image 35:
#   total boxes: 0
#   cars: 0
#   persons: 0
#   avg confidence: 0.000
#
# Image 36:
#   total boxes: 9
#   cars: 5
#   persons: 0
#   avg confidence: 0.377
#
# Image 37:
#   total boxes: 7
#   cars: 3
#   persons: 0
#   avg confidence: 0.335
#
# Image 38:
#   total boxes: 38
#   cars: 16
#   persons: 6
#   avg confidence: 0.243
#
# Image 39:
#   total boxes: 5
#   cars: 1
#   persons: 0
#   avg confidence: 0.203
#
# Image 40:
#   total boxes: 0
#   cars: 0
#   persons: 0
#   avg confidence: 0.000
#
# Image 41:
#   total boxes: 5
#   cars: 2
#   persons: 0
#   avg confidence: 0.312
#
# Image 42:
#   total boxes: 4
#   cars: 1
#   persons: 0
#   avg confidence: 0.352
#
# Image 43:
#   total boxes: 9
#   cars: 6
#   persons: 1
#   avg confidence: 0.342
#
# Image 44:
#   total boxes: 33
#   cars: 21
#   persons: 1
#   avg confidence: 0.316
#
# Image 45:
#   total boxes: 9
#   cars: 3
#   persons: 0
#   avg confidence: 0.316
#
# Image 46:
#   total boxes: 2
#   cars: 1
#   persons: 0
#   avg confidence: 0.695
#
# Image 47:
#   total boxes: 7
#   cars: 3
#   persons: 0
#   avg confidence: 0.182
#
# Image 48:
#   total boxes: 3
#   cars: 0
#   persons: 0
#   avg confidence: 0.282
#
# Image 49:
#   total boxes: 4
#   cars: 1
#   persons: 0
#   avg confidence: 0.144
#
# Image 50:
#   total boxes: 12
#   cars: 8
#   persons: 0
#   avg confidence: 0.472
#
# Image 51:
#   total boxes: 2
#   cars: 0
#   persons: 0
#   avg confidence: 0.129
#
# Image 52:
#   total boxes: 15
#   cars: 7
#   persons: 4
#   avg confidence: 0.235
#
# Image 53:
#   total boxes: 10
#   cars: 4
#   persons: 0
#   avg confidence: 0.216
#
# Image 54:
#   total boxes: 13
#   cars: 6
#   persons: 0
#   avg confidence: 0.328
#
# Image 55:
#   total boxes: 6
#   cars: 1
#   persons: 1
#   avg confidence: 0.165
#
# Image 56:
#   total boxes: 5
#   cars: 3
#   persons: 1
#   avg confidence: 0.447
#
# Image 57:
#   total boxes: 7
#   cars: 2
#   persons: 0
#   avg confidence: 0.209
#
# Image 58:
#   total boxes: 8
#   cars: 2
#   persons: 1
#   avg confidence: 0.182
#
# Image 59:
#   total boxes: 13
#   cars: 6
#   persons: 3
#   avg confidence: 0.245
#
# Image 60:
#   total boxes: 4
#   cars: 1
#   persons: 0
#   avg confidence: 0.200
#
# Image 61:
#   total boxes: 5
#   cars: 1
#   persons: 0
#   avg confidence: 0.195
#
# Image 62:
#   total boxes: 8
#   cars: 8
#   persons: 0
#   avg confidence: 0.449
#
# Image 63:
#   total boxes: 5
#   cars: 1
#   persons: 1
#   avg confidence: 0.210
#
# Image 64:
#   total boxes: 2
#   cars: 1
#   persons: 0
#   avg confidence: 0.358
#
# Image 65:
#   total boxes: 2
#   cars: 0
#   persons: 0
#   avg confidence: 0.142
#
# Image 66:
#   total boxes: 3
#   cars: 0
#   persons: 0
#   avg confidence: 0.127
#
# Image 67:
#   total boxes: 0
#   cars: 0
#   persons: 0
#   avg confidence: 0.000
#
# Image 68:
#   total boxes: 4
#   cars: 0
#   persons: 0
#   avg confidence: 0.284
#
# Image 69:
#   total boxes: 5
#   cars: 0
#   persons: 0
#   avg confidence: 0.440
#
# Image 70:
#   total boxes: 10
#   cars: 1
#   persons: 2
#   avg confidence: 0.289
#
# Image 71:
#   total boxes: 7
#   cars: 0
#   persons: 1
#   avg confidence: 0.244
#
# Image 72:
#   total boxes: 5
#   cars: 2
#   persons: 0
#   avg confidence: 0.279
#
# Image 73:
#   total boxes: 16
#   cars: 13
#   persons: 1
#   avg confidence: 0.478
#
# Image 74:
#   total boxes: 5
#   cars: 1
#   persons: 0
#   avg confidence: 0.279
#
# Image 75:
#   total boxes: 0
#   cars: 0
#   persons: 0
#   avg confidence: 0.000
#
# Image 76:
#   total boxes: 2
#   cars: 0
#   persons: 0
#   avg confidence: 0.157
#
# Image 77:
#   total boxes: 4
#   cars: 1
#   persons: 0
#   avg confidence: 0.352
#
# Image 78:
#   total boxes: 0
#   cars: 0
#   persons: 0
#   avg confidence: 0.000
#
# Image 79:
#   total boxes: 5
#   cars: 1
#   persons: 1
#   avg confidence: 0.241
#
# Image 80:
#   total boxes: 20
#   cars: 11
#   persons: 0
#   avg confidence: 0.232
#
# Image 81:
#   total boxes: 4
#   cars: 0
#   persons: 0
#   avg confidence: 0.435
#
# Image 82:
#   total boxes: 4
#   cars: 1
#   persons: 0
#   avg confidence: 0.238
#
# Image 83:
#   total boxes: 10
#   cars: 4
#   persons: 1
#   avg confidence: 0.321
#
# Image 84:
#   total boxes: 4
#   cars: 3
#   persons: 0
#   avg confidence: 0.489
#
# Image 85:
#   total boxes: 6
#   cars: 3
#   persons: 0
#   avg confidence: 0.356
#
# Image 86:
#   total boxes: 5
#   cars: 2
#   persons: 2
#   avg confidence: 0.407
#
# Image 87:
#   total boxes: 9
#   cars: 6
#   persons: 1
#   avg confidence: 0.359
#
# Image 88:
#   total boxes: 1
#   cars: 0
#   persons: 0
#   avg confidence: 0.163
#
# Image 89:
#   total boxes: 36
#   cars: 20
#   persons: 8
#   avg confidence: 0.229
#
# Image 90:
#   total boxes: 4
#   cars: 1
#   persons: 0
#   avg confidence: 0.127
#
# Image 91:
#   total boxes: 8
#   cars: 0
#   persons: 4
#   avg confidence: 0.208
#
# Image 92:
#   total boxes: 1
#   cars: 0
#   persons: 0
#   avg confidence: 0.201
#
# Image 93:
#   total boxes: 5
#   cars: 1
#   persons: 1
#   avg confidence: 0.191
#
# Image 94:
#   total boxes: 5
#   cars: 4
#   persons: 0
#   avg confidence: 0.465
#
# Image 95:
#   total boxes: 9
#   cars: 4
#   persons: 3
#   avg confidence: 0.295
#
# Image 96:
#   total boxes: 15
#   cars: 12
#   persons: 0
#   avg confidence: 0.347
#
# Image 97:
#   total boxes: 11
#   cars: 8
#   persons: 1
#   avg confidence: 0.223
#
# Image 98:
#   total boxes: 3
#   cars: 0
#   persons: 1
#   avg confidence: 0.237
#
# Image 99:
#   total boxes: 16
#   cars: 11
#   persons: 0
#   avg confidence: 0.322
#
# Image 100:
#   total boxes: 7
#   cars: 3
#   persons: 0
#   avg confidence: 0.223
#
# Image 101:
#   total boxes: 10
#   cars: 3
#   persons: 0
#   avg confidence: 0.213
#
# Image 102:
#   total boxes: 1
#   cars: 0
#   persons: 0
#   avg confidence: 0.113
#
# Image 103:
#   total boxes: 7
#   cars: 5
#   persons: 0
#   avg confidence: 0.393
#
# Image 104:
#   total boxes: 13
#   cars: 2
#   persons: 0
#   avg confidence: 0.220
#
# Image 105:
#   total boxes: 3
#   cars: 1
#   persons: 0
#   avg confidence: 0.179
#
# Image 106:
#   total boxes: 3
#   cars: 0
#   persons: 1
#   avg confidence: 0.232
#
# Image 107:
#   total boxes: 9
#   cars: 5
#   persons: 1
#   avg confidence: 0.366
#
# Image 108:
#   total boxes: 16
#   cars: 6
#   persons: 1
#   avg confidence: 0.320
#
# Image 109:
#   total boxes: 3
#   cars: 1
#   persons: 1
#   avg confidence: 0.125
#
# Image 110:
#   total boxes: 7
#   cars: 1
#   persons: 0
#   avg confidence: 0.165
#
# Image 111:
#   total boxes: 6
#   cars: 1
#   persons: 0
#   avg confidence: 0.268
#
# Image 112:
#   total boxes: 2
#   cars: 0
#   persons: 0
#   avg confidence: 0.210
#
# Image 113:
#   total boxes: 5
#   cars: 4
#   persons: 1
#   avg confidence: 0.266
#
# Image 114:
#   total boxes: 17
#   cars: 3
#   persons: 0
#   avg confidence: 0.241
#
# Image 115:
#   total boxes: 16
#   cars: 11
#   persons: 0
#   avg confidence: 0.348
#
# Image 116:
#   total boxes: 6
#   cars: 1
#   persons: 0
#   avg confidence: 0.301
#
# Image 117:
#   total boxes: 30
#   cars: 18
#   persons: 2
#   avg confidence: 0.330
#
# Image 118:
#   total boxes: 18
#   cars: 7
#   persons: 0
#   avg confidence: 0.276
#
# Image 119:
#   total boxes: 13
#   cars: 7
#   persons: 3
#   avg confidence: 0.294
#
# Image 120:
#   total boxes: 6
#   cars: 2
#   persons: 1
#   avg confidence: 0.228
#
# Image 121:
#   total boxes: 3
#   cars: 0
#   persons: 0
#   avg confidence: 0.122
#
# Image 122:
#   total boxes: 2
#   cars: 0
#   persons: 0
#   avg confidence: 0.149
#
# Image 123:
#   total boxes: 26
#   cars: 16
#   persons: 3
#   avg confidence: 0.299
#
# Image 124:
#   total boxes: 4
#   cars: 1
#   persons: 0
#   avg confidence: 0.142
#
# Image 125:
#   total boxes: 19
#   cars: 16
#   persons: 0
#   avg confidence: 0.362
#
# Image 126:
#   total boxes: 12
#   cars: 1
#   persons: 4
#   avg confidence: 0.338
#
# Image 127:
#   total boxes: 12
#   cars: 1
#   persons: 0
#   avg confidence: 0.296
#
# Image 128:
#   total boxes: 8
#   cars: 2
#   persons: 1
#   avg confidence: 0.213
#
# Image 129:
#   total boxes: 2
#   cars: 0
#   persons: 0
#   avg confidence: 0.176
#
# Image 130:
#   total boxes: 23
#   cars: 22
#   persons: 0
#   avg confidence: 0.331
#
# Image 131:
#   total boxes: 5
#   cars: 1
#   persons: 2
#   avg confidence: 0.324
#
# Image 132:
#   total boxes: 23
#   cars: 19
#   persons: 0
#   avg confidence: 0.323
#
# Image 133:
#   total boxes: 3
#   cars: 1
#   persons: 0
#   avg confidence: 0.239
#
# Image 134:
#   total boxes: 13
#   cars: 11
#   persons: 1
#   avg confidence: 0.525
#
# Image 135:
#   total boxes: 5
#   cars: 0
#   persons: 0
#   avg confidence: 0.288
#
# Image 136:
#   total boxes: 1
#   cars: 0
#   persons: 0
#   avg confidence: 0.104
#
# Image 137:
#   total boxes: 9
#   cars: 2
#   persons: 1
#   avg confidence: 0.212
#
# Image 138:
#   total boxes: 3
#   cars: 0
#   persons: 1
#   avg confidence: 0.126
#
# Image 139:
#   total boxes: 2
#   cars: 1
#   persons: 0
#   avg confidence: 0.487
#
# Image 140:
#   total boxes: 12
#   cars: 5
#   persons: 2
#   avg confidence: 0.264
#
# Image 141:
#   total boxes: 3
#   cars: 0
#   persons: 0
#   avg confidence: 0.157
#
# Image 142:
#   total boxes: 8
#   cars: 1
#   persons: 0
#   avg confidence: 0.130
#
# Image 143:
#   total boxes: 16
#   cars: 8
#   persons: 1
#   avg confidence: 0.306
#
# Image 144:
#   total boxes: 4
#   cars: 0
#   persons: 0
#   avg confidence: 0.432
#
# Image 145:
#   total boxes: 1
#   cars: 0
#   persons: 0
#   avg confidence: 0.589
#
# Image 146:
#   total boxes: 6
#   cars: 3
#   persons: 0
#   avg confidence: 0.318
#
# Image 147:
#   total boxes: 7
#   cars: 1
#   persons: 0
#   avg confidence: 0.184
#
# Image 148:
#   total boxes: 6
#   cars: 5
#   persons: 0
#   avg confidence: 0.524
#
# Image 149:
#   total boxes: 23
#   cars: 17
#   persons: 1
#   avg confidence: 0.240
#
# Image 150:
#   total boxes: 5
#   cars: 2
#   persons: 1
#   avg confidence: 0.480
#
# Image 151:
#   total boxes: 9
#   cars: 6
#   persons: 2
#   avg confidence: 0.515
#
# Image 152:
#   total boxes: 6
#   cars: 2
#   persons: 0
#   avg confidence: 0.367
#
# Image 153:
#   total boxes: 8
#   cars: 1
#   persons: 0
#   avg confidence: 0.187
#
# Image 154:
#   total boxes: 15
#   cars: 13
#   persons: 0
#   avg confidence: 0.334
#
# Image 155:
#   total boxes: 17
#   cars: 16
#   persons: 0
#   avg confidence: 0.390
#
# Image 156:
#   total boxes: 7
#   cars: 4
#   persons: 0
#   avg confidence: 0.307
#
# Image 157:
#   total boxes: 3
#   cars: 0
#   persons: 1
#   avg confidence: 0.118
#
# Image 158:
#   total boxes: 4
#   cars: 1
#   persons: 0
#   avg confidence: 0.117
#
# Image 159:
#   total boxes: 3
#   cars: 0
#   persons: 0
#   avg confidence: 0.178
#
# Image 160:
#   total boxes: 5
#   cars: 0
#   persons: 0
#   avg confidence: 0.142
#
# Summary:
#   avg boxes/image: 8.14
#   max boxes/image: 38
#   min boxes/image: 0
#
# Total boxes across all images: 1303

# %% [markdown]
# # IoU calculations

# %% [markdown]
# ## Baseline Python IoU calculation

# %%
# baseline Python IoU + benchmark
import time
import numpy as np

def compute_iou_python(box_a, box_b):
    x_left = max(box_a[0], box_b[0])
    y_top = max(box_a[1], box_b[1])
    x_right = min(box_a[2], box_b[2])
    y_bottom = min(box_a[3], box_b[3])

    inter_w = max(0.0, x_right - x_left)
    inter_h = max(0.0, y_bottom - y_top)
    intersection = inter_w * inter_h

    area_a = max(0.0, box_a[2] - box_a[0]) * max(0.0, box_a[3] - box_a[1])
    area_b = max(0.0, box_b[2] - box_b[0]) * max(0.0, box_b[3] - box_b[1])

    union = area_a + area_b - intersection

    if union <= 0.0:
        return 0.0

    return intersection / union


def iou_matrix_python(boxes):
    n = len(boxes)
    out = np.zeros((n, n), dtype=np.float32)

    for i in range(n):
        for j in range(n):
            out[i, j] = compute_iou_python(boxes[i], boxes[j])

    return out

# %% [markdown]
# ## Numba JIT IoU implications

# %%
import time
import numpy as np
from numba import njit

# ----------------------------
# Numba IoU implementation
# ----------------------------
@njit
def compute_iou_numba(box_a, box_b):
    x_left = max(box_a[0], box_b[0])
    y_top = max(box_a[1], box_b[1])
    x_right = min(box_a[2], box_b[2])
    y_bottom = min(box_a[3], box_b[3])

    inter_w = max(0.0, x_right - x_left)
    inter_h = max(0.0, y_bottom - y_top)
    intersection = inter_w * inter_h

    area_a = max(0.0, box_a[2] - box_a[0]) * max(0.0, box_a[3] - box_a[1])
    area_b = max(0.0, box_b[2] - box_b[0]) * max(0.0, box_b[3] - box_b[1])

    union = area_a + area_b - intersection
    if union <= 0.0:
        return 0.0

    return intersection / union


@njit
def iou_matrix_numba(boxes):
    n = boxes.shape[0]
    out = np.zeros((n, n), dtype=np.float32)

    for i in range(n):
        for j in range(n):
            out[i, j] = compute_iou_numba(boxes[i], boxes[j])

    return out

# %% [markdown]
# ## Numba JIT Cuda

# %%
import time
import numpy as np
from numba import cuda


@cuda.jit(device=True)
def compute_iou_device_cuda(a, b):
    x_left = max(a[0], b[0])
    y_top = max(a[1], b[1])
    x_right = min(a[2], b[2])
    y_bottom = min(a[3], b[3])

    inter_w = max(0.0, x_right - x_left)
    inter_h = max(0.0, y_bottom - y_top)
    intersection = inter_w * inter_h

    area_a = max(0.0, a[2] - a[0]) * max(0.0, a[3] - a[1])
    area_b = max(0.0, b[2] - b[0]) * max(0.0, b[3] - b[1])

    union = area_a + area_b - intersection

    if union <= 0.0:
        return 0.0

    return intersection / union


@cuda.jit
def iou_matrix_kernel_cuda(boxes, out):
    i, j = cuda.grid(2)

    n = boxes.shape[0]

    if i < n and j < n:
        out[i, j] = compute_iou_device_cuda(boxes[i], boxes[j])


def iou_matrix_cuda(boxes):
    boxes = np.asarray(boxes, dtype=np.float32)
    boxes = np.ascontiguousarray(boxes)

    n = boxes.shape[0]
    out = np.empty((n, n), dtype=np.float32)

    d_boxes = cuda.to_device(boxes)
    d_out = cuda.device_array_like(out)

    threads_per_block = (16, 16)
    blocks_per_grid = (
        (n + threads_per_block[0] - 1) // threads_per_block[0],
        (n + threads_per_block[1] - 1) // threads_per_block[1],
    )

    iou_matrix_kernel_cude[blocks_per_grid, threads_per_block](d_boxes, d_out)
    cuda.synchronize()

    return d_out.copy_to_host()

# %% [markdown]
# # Benchmark: First-run comparison: Python execution vs Numba compile + execution

# %%
import time
import numpy as np

def get_numba_first_call_time(all_boxes):
    if "numba_first_call_time" in globals():
        return numba_first_call_time

    for boxes in all_boxes:
        if len(boxes) > 0:
            boxes_f32 = boxes.astype(np.float32)
            start = time.perf_counter()
            _ = iou_matrix_numba(boxes_f32)
            return time.perf_counter() - start

numba_first_call_time = get_numba_first_call_time(all_boxes)
print(f"Stored Numba first-call time: {numba_first_call_time:.6f} s")
# Out:
# Stored Numba first-call time: 1.496187 s

# %%
import time
import numpy as np

if "python_first_call_time" not in globals():
    for boxes in all_boxes:
        if len(boxes) > 0:
            boxes_f32 = boxes.astype(np.float32)

            start = time.perf_counter()
            _ = iou_matrix_python(boxes_f32)
            python_first_call_time = time.perf_counter() - start
            break

print(f"Stored Python first-call time: {python_first_call_time:.6f} s")
# Out:
# Stored Python first-call time: 0.000803 s

# %%
iou_matrix_cuda(boxes_f32)
# Out:
# ---------------------------------------------------------------------------
# CudaSupportError                          Traceback (most recent call last)
# /tmp/ipykernel_4512/1003257498.py in <cell line: 0>()
# ----> 1 iou_matrix_cuda(boxes_f32)
#
# /tmp/ipykernel_4512/1035919255.py in iou_matrix_cuda(boxes)
#      43     out = np.empty((n, n), dtype=np.float32)
#      44
# ---> 45     d_boxes = cuda.to_device(boxes)
#      46     d_out = cuda.device_array_like(out)
#      47
#
# /usr/local/lib/python3.12/dist-packages/numba/cuda/cudadrv/devices.py in _require_cuda_context(*args, **kws)
#     229     @functools.wraps(fn)
#     230     def _require_cuda_context(*args, **kws):
# --> 231         with _runtime.ensure_context():
#     232             return fn(*args, **kws)
#     233
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.12/dist-packages/numba/cuda/cudadrv/devices.py in ensure_context(self)
#     119         any top-level Numba CUDA API.
#     120         """
# --> 121         with driver.get_active_context():
#     122             oldctx = self._get_attached_context()
#     123             newctx = self.get_or_create_context(None)
#
# /usr/local/lib/python3.12/dist-packages/numba/cuda/cudadrv/driver.py in __enter__(self)
#     493             else:
#     494                 hctx = drvapi.cu_context(0)
# --> 495                 driver.cuCtxGetCurrent(byref(hctx))
#     496                 hctx = hctx if hctx.value else None
#     497
#
# /usr/local/lib/python3.12/dist-packages/numba/cuda/cudadrv/driver.py in __getattr__(self, fname)
#     293
#     294         if self.initialization_error is not None:
# --> 295             raise CudaSupportError("Error at driver init: \n%s:" %
#     296                                    self.initialization_error)
#     297
#
# CudaSupportError: Error at driver init:
#
# CUDA driver library cannot be found.
# If you are sure that a CUDA driver is installed,
# try setting environment variable NUMBA_CUDA_DRIVER
# with the file path of the CUDA driver shared library.
# :
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt

labels = ["Python first run", "Numba first run\n(compile + execute)"]
times = [python_first_call_time, numba_first_call_time]

plt.figure(figsize=(6, 4))
plt.bar(labels, times)
plt.ylabel("Runtime (seconds)")
plt.title("First-run comparison: Python vs Numba")
plt.show()

# %% [markdown]
# # Benchmark: Python baseline vs Numba JIT implementation
#
# This section compares the execution time of the IoU computation implemented in pure Python and using Numba JIT compilation.
#
# 50 repeats x 160 images

# %%
# ----------------------------
# Repeated benchmark functions
# ----------------------------
def benchmark_python_iou_repeated(all_boxes, repeats):
    start = time.perf_counter()
    final_outputs = []

    for r in range(repeats):
        run_outputs = []
        for boxes in all_boxes:
            if len(boxes) == 0:
                run_outputs.append(np.empty((0, 0), dtype=np.float32))
            else:
                run_outputs.append(iou_matrix_python(boxes.astype(np.float32)))
        if r == repeats - 1:
            final_outputs = run_outputs

    elapsed = time.perf_counter() - start
    return final_outputs, elapsed


def benchmark_numba_iou_repeated(all_boxes, repeats):
    # Warm-up compile
    for boxes in all_boxes:
        if len(boxes) > 0:
            _ = iou_matrix_numba(boxes.astype(np.float32))
            break

    start = time.perf_counter()
    final_outputs = []

    for r in range(repeats):
        run_outputs = []
        for boxes in all_boxes:
            if len(boxes) == 0:
                run_outputs.append(np.empty((0, 0), dtype=np.float32))
            else:
                run_outputs.append(iou_matrix_numba(boxes.astype(np.float32)))
        if r == repeats - 1:
            final_outputs = run_outputs

    elapsed = time.perf_counter() - start
    return final_outputs, elapsed

def benchmark_cuda_iou_repeated(all_boxes, repeats):
    # Warm-up compile
    for boxes in all_boxes:
        if len(boxes) > 0:
            _ = iou_matrix_cuda(boxes.astype(np.float32))
            break

    start = time.perf_counter()
    final_outputs = []

    for r in range(repeats):
        run_outputs = []
        for boxes in all_boxes:
            if len(boxes) == 0:
                run_outputs.append(np.empty((0, 0), dtype=np.float32))
            else:
                run_outputs.append(iou_matrix_cuda(boxes.astype(np.float32)))
        if r == repeats - 1:
            final_outputs = run_outputs

    elapsed = time.perf_counter() - start
    return final_outputs, elapsed


# ----------------------------
# Run repeated benchmark
# ----------------------------
repeats = 50

python_outputs, python_elapsed = benchmark_python_iou_repeated(all_boxes, repeats)
numba_outputs, numba_elapsed = benchmark_numba_iou_repeated(all_boxes, repeats)
cuda_outputs, cuda_elapsed = benchmark_cuda_iou_repeated(all_boxes, repeats)

print(f"Python repeated IoU time: {python_elapsed:.4f} s")
print(f"Numba repeated IoU time:  {numba_elapsed:.4f} s")
print(f"Speedup: {python_elapsed / numba_elapsed:.2f}x")
print(f"Cuda repeated IoU time:  {cuda_elapsed:.4f} s")
print(f"Speedup cuda: {python_elapsed / cuda_elapsed:.2f}x")


# ----------------------------
# Correctness check
# ----------------------------
all_match = True
max_abs_diff = 0.0

for py_mat, nb_mat in zip(python_outputs, numba_outputs):
    if py_mat.shape != nb_mat.shape:
        all_match = False
        print("Shape mismatch found.")
        break

    if py_mat.size > 0:
        diff = np.max(np.abs(py_mat - nb_mat))
        max_abs_diff = max(max_abs_diff, float(diff))
        mean_diff = np.mean(np.abs(py_mat - nb_mat))
        if not np.allclose(py_mat, nb_mat, atol=1e-6):
            all_match = False
            break

print("\nCorrectness check:")
print(f"  outputs match: {all_match}")
print(f"  max abs diff:  {max_abs_diff:.8f}")
print(f"  mean abs diff:  {mean_diff:.8f}")
# Out:
# ---------------------------------------------------------------------------
# CudaSupportError                          Traceback (most recent call last)
# /tmp/ipykernel_4512/1819889978.py in <cell line: 0>()
#      74 python_outputs, python_elapsed = benchmark_python_iou_repeated(all_boxes, repeats)
#      75 numba_outputs, numba_elapsed = benchmark_numba_iou_repeated(all_boxes, repeats)
# ---> 76 cuda_outputs, cuda_elapsed = benchmark_cuda_iou_repeated(all_boxes, repeats)
#      77
#      78 print(f"Python repeated IoU time: {python_elapsed:.4f} s")
#
# /tmp/ipykernel_4512/1819889978.py in benchmark_cuda_iou_repeated(all_boxes, repeats)
#      47     for boxes in all_boxes:
#      48         if len(boxes) > 0:
# ---> 49             _ = iou_matrix_cuda(boxes.astype(np.float32))
#      50             break
#      51
#
# /tmp/ipykernel_4512/1035919255.py in iou_matrix_cuda(boxes)
#      43     out = np.empty((n, n), dtype=np.float32)
#      44
# ---> 45     d_boxes = cuda.to_device(boxes)
#      46     d_out = cuda.device_array_like(out)
#      47
#
# /usr/local/lib/python3.12/dist-packages/numba/cuda/cudadrv/devices.py in _require_cuda_context(*args, **kws)
#     229     @functools.wraps(fn)
#     230     def _require_cuda_context(*args, **kws):
# --> 231         with _runtime.ensure_context():
#     232             return fn(*args, **kws)
#     233
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.12/dist-packages/numba/cuda/cudadrv/devices.py in ensure_context(self)
#     119         any top-level Numba CUDA API.
#     120         """
# --> 121         with driver.get_active_context():
#     122             oldctx = self._get_attached_context()
#     123             newctx = self.get_or_create_context(None)
#
# /usr/local/lib/python3.12/dist-packages/numba/cuda/cudadrv/driver.py in __enter__(self)
#     493             else:
#     494                 hctx = drvapi.cu_context(0)
# --> 495                 driver.cuCtxGetCurrent(byref(hctx))
#     496                 hctx = hctx if hctx.value else None
#     497
#
# /usr/local/lib/python3.12/dist-packages/numba/cuda/cudadrv/driver.py in __getattr__(self, fname)
#     293
#     294         if self.initialization_error is not None:
# --> 295             raise CudaSupportError("Error at driver init: \n%s:" %
#     296                                    self.initialization_error)
#     297
#
# CudaSupportError: Error at driver init:
#
# CUDA driver library cannot be found.
# If you are sure that a CUDA driver is installed,
# try setting environment variable NUMBA_CUDA_DRIVER
# with the file path of the CUDA driver shared library.
# :
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt

labels = ["Python (total)", "Numba JIT (total)", "Cuda JIT (total)"]
times = [python_elapsed, numba_elapsed, cuda_elapsed]

plt.figure(figsize=(6, 4))
plt.bar(labels, times)
plt.ylabel("Runtime (seconds)")
plt.title("Total IoU runtime: Python vs Numba JIT vs Cuda")
plt.show()

# %%
import matplotlib.pyplot as plt

num_images = sum(1 for b in all_boxes if len(b) > 0)

python_per_image = python_elapsed / (repeats * num_images)
numba_per_image = numba_elapsed / (repeats * num_images)
cuda_per_image = cuda_elapsed / (repeats * num_images)

# Convert to milliseconds
python_ms = python_per_image * 1000
numba_ms = numba_per_image * 1000
cuda_ms = cuda_per_image * 1000

print(f"python runtime (ms) per image: {python_ms:.4f}")
print(f"Numba runtime (ms) per image: {numba_ms:.4f}")
print(f"Cuda runtime (ms) per image: {cuda_ms:.4f}")

labels = ["Python (per image)", "Numba JIT (per image)", "Cuda JIT (per image)"]
times = [python_ms, numba_ms, cuda_ms]

plt.figure(figsize=(6, 4))
plt.bar(labels, times)
plt.ylabel("Time per image (ms)")
plt.title("Per-image IoU computation time")
plt.show()

# %% [markdown]
# # Appendix

# %% [markdown]
# # hardware info

# %%
from psutil import *
# This code will return the number of CPU
print("Number of CPU: ", cpu_count())
print("virtual memory: ", virtual_memory())
# This code will return the CPU info
# !cat /proc/cpuinfo

# %% [markdown]
# ## GPU?
# we don't really need to check this anymore. or perhaps we could do a comparison with GPU enabled for JIT to check if it makes a difference.

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("No GPU detected.")
